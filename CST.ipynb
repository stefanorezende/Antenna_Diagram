# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import pandas as pd
import numpy as np
from scipy import interpolate

# %%
df = pd.read_csv('CST\\2AHHF06.txt', sep='\s+', skiprows=2, names= ['Theta [deg.]','Phi [deg.]','Abs(Grlz)[dBi]',  'Abs(Theta)[dBi]',  'Phase(Theta)[deg.]', 'Abs(Phi)[dBi]', 'Phase(Phi)[deg.]', 'Ax.Ratio[dB]'])
df
# Out:
#      Theta [deg.]  Phi [deg.]  Abs(Grlz)[dBi]  Abs(Theta)[dBi]  \
# 0             0.0        90.0         -1.0610         -1.06100
# 1             1.0        90.0         -1.3800         -1.38000
# 2             2.0        90.0         -1.7170         -1.71700
# 3             3.0        90.0         -2.0730         -2.07300
# 4             4.0        90.0         -2.4480         -2.44800
# ..            ...         ...             ...              ...
# 355           5.0       270.0          0.3021          0.30200
# 356           4.0       270.0          0.0585          0.05838
# 357           3.0       270.0         -0.1990         -0.19910
# 358           2.0       270.0         -0.4709         -0.47100
# 359           1.0       270.0         -0.7579         -0.75810
#
#      Phase(Theta)[deg.]  Abs(Phi)[dBi]  Phase(Phi)[deg.]  Ax.Ratio[dB]
# 0               237.110         -46.20           228.416          40.0
# 1               236.825         -46.38           229.175          40.0
# 2               236.526         -46.56           229.956          40.0
# 3               236.209         -46.74           230.758          40.0
# 4               235.872         -46.93           231.584          40.0
# ..                  ...            ...               ...           ...
# 355              58.367         -45.40            44.902          40.0
# 356              58.132         -45.55            45.570          40.0
# 357              57.891         -45.71            46.255          40.0
# 358              57.641         -45.87            46.957          40.0
# 359              57.381         -46.03            47.677          40.0
#
# [360 rows x 8 columns]

# %%
df['POSr'] = np.radians(range(90,450, 1))

# %%
fig = plt.figure(figsize=(6, 6))
ax = fig.add_subplot(111, projection='polar')
ax.plot(df['POSr'], df['Abs(Theta)[dBi]'], label='Dados de Exemplo', color='blue')
plt.yticks(range(round(max(df['Abs(Theta)[dBi]'])-20), round(max(df['Abs(Theta)[dBi]'])), 3))

ax.set(ylim=(max(df['Abs(Theta)[dBi]'])-20, max(df['Abs(Theta)[dBi]'])))
ax.set_title('Gráfico Polar Personalizado')
ax.legend()
plt.show()
